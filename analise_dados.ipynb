# %% [markdown]
# <a href="https://colab.research.google.com/github/luizarthurpe/analise-de-dados-python/blob/main/analise_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
aluguel_casa = pd.read_excel('houses_rent.xlsx')

# %%
logistica_db.head()
# Out:
#    Viagem Data Pedido Data Entrega  Prazo Entrega  \
# 0       1  2022-01-01   2022-01-11             11
# 1       2  2022-01-01   2022-01-10              3
# 2       3  2022-01-01   2022-01-04             10
# 3       4  2022-01-01   2022-01-02             12
# 4       5  2022-01-01   2022-01-06              6
#
#                                             Endereço Nome Motorista Sobrenome  \
# 0  R. Teodoro Sampaio, 954 - Pinheiros, São Paulo...        Leandro  Coutinho
# 1  Shopping Barra - Av. Centenário, 2992 - Barra,...       Fernanda     Rocha
# 2  R. Teodoro Sampaio, 954 - Pinheiros, São Paulo...         Victor   Fonseca
# 3  R. Teodoro Sampaio, 954 - Pinheiros, São Paulo...          Julia   Freitas
# 4  Av. Borges de Medeiros, 3120 - Praia de Belas,...      Frederico     Vidal
#
#           Marca/Veículo  Valor do Frete Líquido     Km  Custo Combustível  \
# 0        Scania - TRUCK                  562.70  12.51              41.28
# ...

# %%
logistica_db.tail()
# Out:
#        Viagem Data Pedido Data Entrega  Prazo Entrega  \
# 58975   58976  2023-12-30   2023-12-31             11
# 58976   58977  2023-12-30   2023-12-31              8
# 58977   58978  2023-12-30   2023-12-31              5
# 58978   58979  2023-12-30   2024-01-01              2
# 58979   58980  2023-12-30   2024-01-01              3
#
#                                                 Endereço Nome Motorista  \
# 58975  Rua Antônio Lumack do Monte, 203 - 1 - Boa Via...         Filipe
# 58976  Av. Goiás Norte, 3.592 - quadra 2.1 - St. Mal....          Maria
# 58977  Shopping Barra - Av. Centenário, 2992 - Barra,...       Carolina
# 58978  R. Teodoro Sampaio, 954 - Pinheiros, São Paulo...         Poline
# 58979  R. Teodoro Sampaio, 954 - Pinheiros, São Paulo...          Bruno
#
#       Sobrenome         Marca/Veículo  Valor do Frete Líquido     Km  \
# 58975     Tabet   Mercedes-Benz - 3/4                  651.75  26.55
# ...

# %%
logistica_db = logistica_db.rename(columns={'Data Pedido':'Data do Pedido'})

# %%
logistica_db.head()
# Out:
#    Viagem Data do Pedido Data Entrega  Prazo Entrega  \
# 0       1     2022-01-01   2022-01-11             11
# 1       2     2022-01-01   2022-01-10              3
# 2       3     2022-01-01   2022-01-04             10
# 3       4     2022-01-01   2022-01-02             12
# 4       5     2022-01-01   2022-01-06              6
#
#                                             Endereço Nome Motorista Sobrenome  \
# 0  R. Teodoro Sampaio, 954 - Pinheiros, São Paulo...        Leandro  Coutinho
# 1  Shopping Barra - Av. Centenário, 2992 - Barra,...       Fernanda     Rocha
# 2  R. Teodoro Sampaio, 954 - Pinheiros, São Paulo...         Victor   Fonseca
# 3  R. Teodoro Sampaio, 954 - Pinheiros, São Paulo...          Julia   Freitas
# 4  Av. Borges de Medeiros, 3120 - Praia de Belas,...      Frederico     Vidal
#
#           Marca/Veículo  Valor do Frete Líquido     Km  Custo Combustível  \
# 0        Scania - TRUCK                  562.70  12.51              41.28
# ...

# %%
logistica_db.dtypes
# Out:
# Viagem                             int64
# Data do Pedido            datetime64[ns]
# Data Entrega              datetime64[ns]
# Prazo Entrega                      int64
# Endereço                          object
# Nome Motorista                    object
# Sobrenome                         object
# Marca/Veículo                     object
# Valor do Frete Líquido           float64
# Km                               float64
# Custo Combustível                float64
# Custo Manutenção                 float64
# Custos Fixos                     float64
# Unnamed: 13                       object
# dtype: object

# %%
logistica_db = logistica_db.astype({'Endereço':'string'})

# %%
logistica_db.dtypes
# Out:
# Viagem                             int64
# Data do Pedido            datetime64[ns]
# Data Entrega              datetime64[ns]
# Prazo Entrega                      int64
# Endereço                  string[python]
# Nome Motorista                    object
# Sobrenome                         object
# Marca/Veículo                     object
# Valor do Frete Líquido           float64
# Km                               float64
# Custo Combustível                float64
# Custo Manutenção                 float64
# Custos Fixos                     float64
# Unnamed: 13                       object
# dtype: object

# %%
logistica_db[['Viagem','Prazo Entrega']]
# Out:
#        Viagem  Prazo Entrega
# 0           1             11
# 1           2              3
# 2           3             10
# 3           4             12
# 4           5              6
# ...       ...            ...
# 58975   58976             11
# 58976   58977              8
# 58977   58978              5
# 58978   58979              2
# 58979   58980              3
#
# [58980 rows x 2 columns]

# %%
logistica_db[['Viagem','Prazo Entrega','Endereço']].describe()
# Out:
#              Viagem  Prazo Entrega
# count  58980.000000   58980.000000
# mean   29490.500000       6.500661
# std    17026.203775       3.451109
# min        1.000000       1.000000
# 25%    14745.750000       3.000000
# 50%    29490.500000       6.000000
# 75%    44235.250000      10.000000
# max    58980.000000      12.000000

# %%
logistica_db = logistica_db[(logistica_db['Custo Combustível']<=40)]
logistica_db.head()
# Out:
#    Viagem Data do Pedido Data Entrega  Prazo Entrega  \
# 2       3     2022-01-01   2022-01-04             10
#
#                                             Endereço Nome Motorista Sobrenome  \
# 2  R. Teodoro Sampaio, 954 - Pinheiros, São Paulo...         Victor   Fonseca
#
#   Marca/Veículo  Valor do Frete Líquido    Km  Custo Combustível  \
# 2  Scania - 3/4                   18.66  0.76                0.3
#
#    Custo Manutenção  Custos Fixos Unnamed: 13
# 2              2.89          3.03         NaN

# %%
logistica_db = logistica_db[(logistica_db['Custo Combustível']<=40) & (logistica_db['Km'] <5)]
logistica_db.head()
# Out:
#     Viagem Data do Pedido Data Entrega  Prazo Entrega  \
# 2        3     2022-01-01   2022-01-04             10
# 5        6     2022-01-01   2022-01-02              8
# 12      13     2022-01-01   2022-01-04             10
# 13      14     2022-01-01   2022-01-02             10
# 14      15     2022-01-01   2022-01-02             10
#
#                                              Endereço Nome Motorista  \
# 2   R. Teodoro Sampaio, 954 - Pinheiros, São Paulo...         Victor
# 5   Rua Antônio Lumack do Monte, 203 - 1 - Boa Via...           João
# 12  Rua Antônio Lumack do Monte, 203 - 1 - Boa Via...          Breno
# 13  Shopping Barra - Av. Centenário, 2992 - Barra,...          Andre
# 14  Av. Barão Homem de Melo, 1389 - Nova Granada, ...        Leandro
#
#    Sobrenome         Marca/Veículo  Valor do Frete Líquido    Km  \
# 2    Fonseca          Scania - 3/4                   18.66  0.76
# 5     Araújo   Mercedes-Benz - VUC                  136.72  3.04
# ...

# %%
logistica_db = logistica_db[(logistica_db['Custo Combustível']==0.30)|(logistica_db['Km'] ==0.76)]
logistica_db[['Custo Combustível','Km']]
# Out:
#    Custo Combustível    Km
# 2                0.3  0.76

# %%
logistica_db = logistica_db.query("Custo Combustível < 40 and Km < 5")
#logistica_db[['Custo Combustível','Km']]
logistica_db.head()
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-65-07f83f889363>", line 1, in <cell line: 1>
#     logistica_db = logistica_db.query("Custo Combustível < 40 and Km < 5")
#
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/frame.py", line 4599, in query
#     res = self.eval(expr, **kwargs)
#
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/frame.py", line 4725, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/computation/eval.py", line 336, in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/computation/expr.py", line 808, in __init__
#     self.terms = self.parse()
#
# ...

# %%
agg_city_price = aluguel_casa.groupby(["city"])["total"].agg("mean").reset_index()
agg_city_price
# Out:
#         city        total
# 0  Barcelona  6457.271099
# 1      Porto  3354.521059

# %%
agg_bath_room_price = aluguel_casa.groupby(["bathroom","rooms"])["total"].agg("mean").reset_index()
agg_bath_room_price
# Out:
#     bathroom  rooms         total
# 0          1      1   2738.951181
# 1          1      2   2499.943489
# 2          1      3   3220.513812
# 3          1      4   5725.571429
# 4          2      1   7901.605042
# 5          2      2   4310.918530
# 6          2      3   5077.840999
# 7          2      4   7042.283784
# 8          2      5   5939.428571
# 9          2      6   3614.500000
# 10         2      7   7218.500000
# 11         3      1   5952.142857
# 12         3      2   7824.506667
# 13         3      3   8189.913043
# 14         3      4   8845.872222
# 15         3      5   8548.100000
# 16         3      6   5267.750000
# 17         3      7   6925.000000
# 18         4      1   7987.500000
# 19         4      2  10288.666667
# 20         4      3   9339.110512
# 21         4      4  11027.088136
# 22         4      5  18031.171429
# 23         4      6  10086.400000
# 24         4      7   8403.250000
# 25         4      8  11970.000000
# ...

# %%
import seaborn as sns

# %%
sns.barplot(agg_bath_room_price, x="rooms", y="total")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-3b31531814e1> in <cell line: 1>()
# ----> 1 sns.barplot(agg_bath_room_price, x="rooms", y="total")
#
# NameError: name 'agg_bath_room_price' is not defined

# %%
sns.barplot(agg_bath_room_price, x="rooms", y="total", color = "blue")
# Out:
# <Axes: xlabel='rooms', ylabel='total'>

# %%
ax = sns.barplot(agg_bath_room_price, x="rooms", y="total");
ax.set(xlabel = "qtd quartos", ylabel = "media do preço");

# %%
ax = sns.barplot(agg_bath_room_price, x="rooms", y="total");
ax.set(xlabel = "qtd quartos", ylabel = "media do preço");

# %%
ax = sns.barplot(data=agg_bath_room_price, x="bathroom", y="total", color = "green");
ax.set(xlabel = "qtd banheiros", ylabel = "media do preço");

# %%
agg_area = aluguel_casa[["area"]]

# %%
sns.histplot(data=agg_area, x="area")
# Out:
# <Axes: xlabel='area', ylabel='Count'>

# %%
agg_area.describe()
# Out:
#                area
# count   6080.000000
# mean     151.143914
# std      375.559485
# min       10.000000
# 25%       58.000000
# 50%      100.000000
# 75%      200.000000
# max    24606.000000

# %%
aluguel_casa = aluguel_casa.query("city == 'Porto'")
aluguel_casa.head()
# Out:
#     index   city  area  rooms  bathroom  parking spaces floor  animal  \
# 1       1  Porto    64      2         1               1    10  accept
# 10     10  Porto    60      1         1               0     6  accept
# 11     11  Porto    64      1         2               1     4  accept
# 15     15  Porto    56      2         1               1     1  accept
# 16     16  Porto   188      2         3               8     -  accept
#
#         furniture  hoa  rent amount  property tax  fire insurance  total
# 1   not furnished  540          820           122              11   1493
# 10  not furnished  480          720            20              10   1230
# 11      furnished  406         1550             0               7   1963
# 15  not furnished  345          950            11              13   1319
# 16  not furnished    0         3010           584              46   3640

# %%
aluguel_casa.describe()
# Out:
#              index          area       rooms    bathroom  parking spaces  \
# count   831.000000    831.000000  831.000000  831.000000      831.000000
# mean   3035.566787    143.867629    2.392298    2.019254        1.630566
# std    1778.156684    455.138673    1.089993    1.400384        1.535752
# min       1.000000     20.000000    1.000000    1.000000        0.000000
# 25%    1472.500000     55.000000    1.500000    1.000000        1.000000
# 50%    3060.000000     77.000000    2.000000    1.000000        1.000000
# 75%    4543.500000    146.500000    3.000000    2.500000        2.000000
# max    6077.000000  12732.000000    7.000000    7.000000        8.000000
#
#         rent amount  property tax  fire insurance         total
# count    831.000000    831.000000      831.000000    831.000000
# mean    2506.210590    157.926594       34.364621   3354.521059
# std     2415.683404    215.065069       34.804939   2961.417481
# ...
